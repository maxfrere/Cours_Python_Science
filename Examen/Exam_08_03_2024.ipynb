# %% [markdown]
# # Examen : Python 3 - 08/03/2024
# ## Consigne :
#
# - Votre fichier/dossier de rendu devra comporter votre nom et prénom sur son nommage (NOM_Prenom.ipny ou NOM_Prenom pour le dossier).
#
# - Un bloc par exercice et chaque bloc doit etre indépendant (import librairie etc...), un fichier par exercice si vous n'utilisez pas jupyter-notebook (exercice_1.py, exercice_2.py etc...).
#
# - Annoter avec # Question N pour localiser vos réponses. Utiliser les commentaires si besoin pour spécifier une réponse littérale si demandé.
#
# - Vous disposez de deux heures et c'est un exercice personelle, tout travail collaboratif sera sanctioné.
#
# ## Formulaire :
#
# Mathématique : Python
#
#
#
# - cos(x) : `np.sin(x)`
# - sin(x) : `np.sin(x)`
# - $e^x$ : `np.exp(x)`
# - $\pi$ : `np.pi`
# - $x^y$ : `x**y`

# %% [markdown]
# # Exercice 1 : Algorithme de rendu de  monaie
#
# Boites à outils à utiliser :
#
# ---
# ```python
# import numpy as np
# ```
# ---
#
# Nous allons ici établir un algorithme de rendu de monnaie qui utilisera un tableau indiquant les billets et pièces disponibles en entrée, ainsi que la somme à rendre. Ce dernier devra être en mesure de nous indiquer en retour combien de chaque billet et pièce, que l'on doit utiliser pour faire le compte.
#
#
# ---
# 1. Créer une boucle permettant d'effectuer ce processus avec le tableau de billet et la somme ci-dessous. Affichant sous forme de liste le nombre de chaque billet à rendre.
# ```python
# tab_billet_1 = np.array([50,20,10,5])
# somme_a_rendre_1 = 285
# ````
# > Pour cet exercice, il est souhaitable d'utiliser la division euclidienne (quotient (//) et reste (%)).
#
# ---
# 2. Adapter votre script pour répondre à la même question avec les paramètres ci-dessous. Ainsi, vous devez adapter la longueur de la liste sortante.
# ```python
# tab_billet_2 = np.array([50,20,10,5,2,1,0.5,0.20,0.10,0.05,0.02,0.01])
# somme_a_rendre_2 = 239.52
# ````
#
# ---
# 3. Généraliser votre script en créant une fonction qui prendra en arguments d'entrée : **la somme** et **le tableau des billets/pièces disponibles. Ce dernier devra renvoyer la **liste indiquant le nombre de chaque billet/pièce à rendre**. Tester votre fonction avec les conditions précédentes et celle ci-dessous :
# ```python
# tab_billet_3 = np.array([50,20,10,2,1,0.01])
# somme_a_rendre_3 = 239.52
# ````
#
# ---
# 4. On peut maintenant associé cela à une réserve de billet (comme une caisse) qui  prendrait la forme d'un tableau supplémentaire. Disposant de 2 billets de 50€, 5 billets de 20€ et 10 éléments pour le reste. Faites en sorte de gérer ce stock en retirant les billets rendus et adaptant si un billet manque en utilisant votre fonction précédente.
# ```python
# tab_billet_3 = np.array([50,20,10,5,2,1])
# stock_billet = np.array([2,5,10,10,3,10])
# somme_a_rendre_3 = 353
# ````

# %% [markdown]
# # Exercice 2 : Courbes et  opérations
#
# Boites à outils à utiliser :
#
# ---
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# ````
# ---
#
# Rappel pour créer une figure :
#
# ---
# ```python
# plt.figure() #Instantier l'objet figure
#
# plt.plot(x,y) #Tracer y en fonction de x
#
# plt.title("Titre") #Mettre un titre (optionel)
# plt.xlabel("x") #Nommer l'axe des x (optionel)
# plt.ylabel("f(x)") #Nommer  l'axe des y (optionel)
# plt.xlim(0,100) #fixer la limite d'affichage sur x (optionel)
#
# plt.show() #Afficher la résultante
# ````
# ---
#
# Nous allons ici étudier les fonctions :
#
# $f(x)=e^{(3-\frac{100}{x^2})}$ avec $x \in [0.1,100[$
#
# $g(y)=20-\frac{y}{8}+2cos(\frac{\pi}{6}y)$ avec $y \in[0.1,100]$
#
# 1. Créer un **tableau** allant 0.1 à 100 (exclu) par pas de 0.1 que vous attribuerez à une variable nommée `x_array`.
# 2. Créer un **tableau** correspondant à **f(x)** appliqué à `x_array` que l'on nommera `f_array`.
# 3. Créer une **figure** représentant la courbe $f(x)=\frac{3x^2}{50}+sin(x)$ et afficher là.
# 4. Créer un **tableau** allant 0 à 100 (inclus) par pas de 0.2 que vous attribuerez à une variable nommée `y_array`.
# 5. Créer un **tableau** correspondant à **g(y)** appliqué à `y_array` que l'on nommera `g_array`.
# 6. Déplacer les deux dernières lignes de votre code pour pouvoir afficher par `plt.plot(x,y)` sur la figure précédent créer, la fonction $g(y)=20-\frac{y}{8}+2cos(\frac{\pi}{6}y)$.
# 7. Adapter les limites d'affichages et titre, si nécessaire.
# 8. Calculer la résultante des intégrales $ \int_{a}^{b} f(x) \approx \sum_{i=0}^{N-1} y_i dx_i = \sum_{i=0}^{N-1} y_i* (x_{i+1}-x_i)$ pour les deux fonctions en utilisant la méthode numérique de votre choix. Attention le pas $dx$ est différent pour les deux courbes $f(x)$ et $g(x)$. Afficher le résultat de ces sommes par le biais de `print()`. Discuter la pertinence de votre choix.
# 9. Afficher la valeur maximale, minimale et les moyennes pour ces deux courbes.
